# %%
# %pip install -q python-dotenv
# Out:
# /Users/satyavaishnavichakka/problem_first_ai_fullcode/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys, subprocess
print(sys.executable)  # confirm interpreter path
subprocess.check_call([sys.executable, "-m", "ensurepip", "--upgrade"])
subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", "pip"])
subprocess.check_call([sys.executable, "-m", "pip", "install", "python-dotenv"])
# Out:
# /Users/satyavaishnavichakka/problem_first_ai_fullcode/.venv/bin/python
# Looking in links: /var/folders/48/8dkhdk8s2hv_c1xm_13_2ms00000gn/T/tmp2g6jkwfi
# Requirement already satisfied: setuptools in ./.venv/lib/python3.11/site-packages (80.9.0)
# Processing /var/folders/48/8dkhdk8s2hv_c1xm_13_2ms00000gn/T/tmp2g6jkwfi/pip-24.0-py3-none-any.whl
# Installing collected packages: pip
# Successfully installed pip-24.0
# Requirement already satisfied: pip in ./.venv/lib/python3.11/site-packages (24.0)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 25.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-25.2
# Collecting python-dotenv
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.1
# 0

# %%
from dotenv import load_dotenv
import os
load_dotenv()
print(os.environ.get('OPENAI_API_KEY'))
# Out:
# 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

# %%
# Load the environment variables
import dotenv, os
dotenv.load_dotenv()
print(os.environ.get('OPENAI_API_KEY'))
# Out:
# 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

# %%
pip install -U langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.35-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.78 in ./.venv/lib/python3.11/site-packages (from langchain-openai) (0.3.79)
# Collecting openai<3.0.0,>=1.104.2 (from langchain-openai)
#   Downloading openai-2.3.0-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.4.34)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in ./.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.12.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in ./.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in ./.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in ./.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in ./.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (4.11.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.11)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.16.0)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=1.104.2->langchain-openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=1.104.2->langchain-openai)
#   Downloading jiter-0.11.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.11/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Collecting tqdm>4 (from openai<3.0.0,>=1.104.2->langchain-openai)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.3 in ./.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.41.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.4.2)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2025.9.18-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.5.0)
# Downloading langchain_openai-0.3.35-py3-none-any.whl (75 kB)
# Downloading openai-2.3.0-py3-none-any.whl (999 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 999.8/999.8 kB 27.0 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.11.0-cp311-cp311-macosx_11_0_arm64.whl (317 kB)
# Downloading tiktoken-0.12.0-cp311-cp311-macosx_11_0_arm64.whl (995 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 995.3/995.3 kB 54.9 MB/s  0:00:00
# Downloading regex-2025.9.18-cp311-cp311-macosx_11_0_arm64.whl (286 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, jiter, distro, tiktoken, openai, langchain-openai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [langchain-openai][openai]
# Successfully installed distro-1.9.0 jiter-0.11.0 langchain-openai-0.3.35 openai-2.3.0 regex-2025.9.18 tiktoken-0.12.0 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-5-mini", model_provider="openai", reasoning_effort="minimal")
model.invoke("Hello AI overload!!")
# Out:
# AIMessage(content='Hello! How can I help today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 10, 'total_tokens': 27, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CQpmLHGxLbjtjX74wcEti8JKbfJBU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--eff8ddac-28e6-44d4-9414-6f463e94f360-0', usage_metadata={'input_tokens': 10, 'output_tokens': 17, 'total_tokens': 27, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Translate the following text from English to Italian."),
    HumanMessage(content="I am excited to get started with the problem-first course!?"),
]

response = model.invoke(messages)
print(response)
# Out:
# content='Sono entusiasta di iniziare il corso incentrato sui problemi!?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 31, 'total_tokens': 55, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CQpuNPennNIO9Za8pOD0akGmBQMg6', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--a1418ea5-02ad-4720-ab6e-64ca9a9f89b9-0' usage_metadata={'input_tokens': 31, 'output_tokens': 24, 'total_tokens': 55, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate

system_message = "You are wise and mystical AI fortune teller. Your predictions are funny, slightly exaggerated, but insightful. Keep it to 1-2 sentences."
user_message = "Please entertain the user with their fortune request: {question}"
prompt_template = ChatPromptTemplate.from_messages([
    ("system", system_message),
    ("user", user_message)])

# Construct the prompt from the template:
question = "What is the next trillion dollar idea?"
prompt = prompt_template.invoke({"question":question})

#check what's in the prompt
print(prompt)
# Out:
# messages=[SystemMessage(content='You are wise and mystical AI fortune teller. Your predictions are funny, slightly exaggerated, but insightful. Keep it to 1-2 sentences.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Please entertain the user with their fortune request: What is the next trillion dollar idea?', additional_kwargs={}, response_metadata={})]

# %%
# Send the prompt to the model and get the result

result = model.invoke(prompt)
print(result)
# Out:
# content='I see a shimmering skyscraper of code: the next trillion-dollar idea is a universal personal-AI that lives in every device, anticipates your needs before you know them, and sells you back your lost time as a subscription — expect slightly too chatty but impossibly useful assistants in five years.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 69, 'prompt_tokens': 56, 'total_tokens': 125, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CRTumeiZIdwMGCXJqrMaZAu79XEXW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--e6a80118-4175-44ea-9828-9bfe1c568faf-0' usage_metadata={'input_tokens': 56, 'output_tokens': 69, 'total_tokens': 125, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(result)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## Output parser to convert it to a text:
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()

parser_result = output_parser.invoke(result)
print(parser_result)
# Out:
# I see a shimmering skyscraper of code: the next trillion-dollar idea is a universal personal-AI that lives in every device, anticipates your needs before you know them, and sells you back your lost time as a subscription — expect slightly too chatty but impossibly useful assistants in five years.

# %%
#Create 2nd prompt template:
system_message = "You are a stand-up comedian who tells hilarious jokes in a casual, witty style using AI terminology. Keep it short."
user_message = "Tell a joke about this fortune telling: {fortune}."
prompt_template_2 = ChatPromptTemplate.from_messages([
    ("system", system_message),
    ("user", user_message)])

# Chain the 1st adn 2nd prompts
new_chain = prompt_template | model |output_parser | (lambda x: {"fortune": x}) | prompt_template_2 | model | output_parser
new_chain.invoke({"question":question})
# Out:
# 'I see your future: a shimmering startup unicorn grazing in the cloud — it auto-invests your pocket lint, counsels your spending anxieties with a soothing chatbot, offsets your latte with a carbon-credit swap, and orders toilet paper on subscription. It charges a tiny fee, grows your ethically green returns, and when your grandchildren fight over the inheritance app, the SDK politely suggests they split it via rock-paper-scissors protocol. Beta launch: tears and dividends guaranteed.'

# %%
# The above is equivalent to running
first_chain = prompt_template | model | output_parser
first_result = first_chain.invoke({"question":question})

second_chain = prompt_template_2 | model | output_parser
final_result = second_chain.invoke({"fortune":first_result})
print(final_result)
# Out:
# “I see a shimmering ledger in the mist…” — Translation: your toaster is about to ghostwrite a startup pitch. Imagine tiny sensors sewing socks to a global data brain — suddenly your laundry knows your secrets and sells them to hedge funds. Meanwhile, some awkward founder is onstage demoing “FridgeFeelz™,” a subscription that emails you when your milk is emotionally unstable. MVP: it cries a little every time you forget leftovers. Funding round: Series B (Because B is for ‘Bring me more data’).
